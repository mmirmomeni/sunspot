# %% [markdown]
# # Stochastic modeling
#
# The idea here is to evolve a probabilistic prediction model.

# %%
import research as r
import scipy
import pandas

def fitness_plots(path, treatment):
    D = r.load_files(r.find_files(path, treatment+"_.*/fitness.dat"))
    D['rmse'] = 100.0 / D['max_fitness'] - 1.0

    figure()
    for i,g in D.groupby('trial'):
        plot(g['update'], g['rmse'])
    ylabel('Sum RMSE, t=1:8')
    xlabel('Update')
    
    figure()
    r.quick_ciplot('update','rmse', D)
    ylabel('Sum RMSE, t=1:8')
    xlabel('Update')

    final = D[D['update']==D['update'].max()]
    print "\nDominant fitness:"
    print final.ix[final['rmse'].idxmin()]
    return D

def rmse_boxplots(path, treatment):
    figure()
    D = r.load_files(r.find_files(path, treatment+"_.*/sunspot_test_rmse.dat"))
    B = D.boxplot(column=['tplus1','tplus2','tplus3','tplus4','tplus5','tplus6','tplus7','tplus8'])
    ylabel("RMSE per horizon")
    
    print "\nMinimum testing RMSE:"
    print D.ix[D['total_rmse'].idxmin()]
    return D

def prediction_horizon(path):
    D = r.load_files(r.find_files(path, "sunspot_test_detail.dat"))
    left, width = 0.1, 0.8
    rect1 = [left, 0.25, width, 0.8]
    rect2 = [left, 0.1, width, 0.1]
    
    for i in range(1,9):
        fig=figure()
        ax1 = fig.add_axes(rect1)
        ax2 = fig.add_axes(rect2, sharex=ax1)

        for label in ax1.get_xticklabels():
            label.set_visible(False)
        
        p1 = ax1.plot(D['observed'], color='blue', label='observed')
        p2 = ax1.plot(D['tplus'+str(i)], color='red', label='t+'+str(i))
        ax1.legend()
        ax1.set_ylabel('Value')
        
        p3 = ax2.vlines(range(0,len(D)), 0, abs(D['observed']-D['tplus'+str(i)]))
        pyplot.locator_params(axis='y', nbins=2)
        ax2.set_ylabel('Error')
        ax2.set_xlabel('Sample')
    return D

# %% [markdown]
# ## 001-space-weather
#
# Below results are for 1 input lag, 8 output predictions:

# %%
p='/Users/dk/research/var/sunspot/001-space-weather'
t='ssnb.'

W = fitness_plots(p,t)
R = rmse_boxplots(p,t)
# Out:
# Dominant fitness:
# update                50000
# mean_generation     255.596
# min_fitness          0.1519
# mean_fitness         0.2195
# max_fitness          0.2444
# treatment             ssnb0
# trial                    19
# rmse               408.1653
# Name: 5009
# Minimum testing RMSE:
# total_rmse    883.2728
# tplus1        105.4156
# tplus2        114.7081
# tplus3        108.6055
# tplus4        110.2471
# tplus5        114.5566
# tplus6         108.094
# tplus7        112.5761
# tplus8        109.0699
# treatment        ssnb0
# trial               27
# Name: 18

# %% [markdown]
# This is odd; why would it flatline so early, and so abruptly?
#
# ### Next:
# - LOD averaging

# %%
p='/Users/dk/research/var/sunspot/002-sw-lags'
t='ssnb.'

W = fitness_plots(p,t)
R = rmse_boxplots(p,t)
# Out:
# Dominant fitness:
# update                50000
# mean_generation     335.168
# min_fitness          0.1583
# mean_fitness         0.2268
# max_fitness          0.2459
# treatment             ssnb0
# trial                     3
# rmse               405.6694
# Name: 10019
#
# Minimum testing RMSE:
# total_rmse    858.2155
# tplus1        114.7661
# tplus2        113.4207
# tplus3         87.2722
# tplus4        114.5414
# tplus5        105.2248
# tplus6        107.1843
# tplus7        115.1011
# tplus8        100.7048
# treatment        ssnb0
# trial               15
# Name: 5
